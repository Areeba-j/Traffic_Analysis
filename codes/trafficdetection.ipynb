# %% [markdown]
# # **Detect traffic and measure Swift Frames Per Second (FPS)**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-123eb5b8-bcc6-4d8c-aa53-6fd5a0945dcf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-123eb5b8-bcc6-4d8c-aa53-6fd5a0945dcf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f234af5f-a760-407f-88d6-c152e78cf2e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f234af5f-a760-407f-88d6-c152e78cf2e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Instantiating pre-trained Yolov8s
# !pip install ultralytics
# !yolo predict model='/content/yolov8s.pt' source='/content/istockphoto-1372690728-640_adpp_is.mp4'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.0/715.0 kB 11.7 MB/s eta 0:00:00
# ...
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# video 1/1 (1/2337) /content/istockphoto-1372690728-640_adpp_is.mp4: 384x640 6 persons, 27 cars, 2 motorcycles, 3 buss, 1 truck, 434.9ms
# video 1/1 (2/2337) /content/istockphoto-1372690728-640_adpp_is.mp4: 384x640 6 persons, 27 cars, 2 motorcycles, 3 buss, 2 trucks, 339.6ms
# video 1/1 (3/2337) /content/istockphoto-1372690728-640_adpp_is.mp4: 384x640 6 persons, 27 cars, 2 motorcycles, 4 buss, 2 trucks, 339.0ms
# video 1/1 (4/2337) /content/istockphoto-1372690728-640_adpp_is.mp4: 384x640 6 persons, 27 cars, 1 motorcycle, 4 buss, 1 truck, 341.6ms
# video 1/1 (5/2337) /content/istockphoto-1372690728-640_adpp_is.mp4: 384x640 7 persons, 27 cars, 1 motorcycle, 4 buss, 1 truck, 333.6ms
# ...

# %%
#Compressing the output video
# !ffmpeg -i {'/content/runs/detect/predict/istockphoto-1372690728-640_adpp_is.avi'} -vcodec libx264  {'final.mp4'}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import cv2

video_path = '/content/final.mp4'

cap = cv2.VideoCapture(video_path)

# Get the frames per second (fps) of the video
fps = cap.get(cv2.CAP_PROP_FPS)

# Print the fps
print(f"Frames per second (fps): {fps}")

cap.release()
# Out:
# Frames per second (fps): 59.0
